# %% [markdown]
# ## Notebook com exemplos de uso e análises

# %%
from getdatalol import GetDataLol
API_KEY = "RGAPI-4125cf79-8553-489b-bc7a-da7510b581df"
objget = GetDataLol(API_KEY, server="BR1", region="AMERICAS", output_path="D:/data/LOL")
# Out:
# Iniciando GetDataLol, para o servidor: BR1 e região: AMERICAS.

# %%
r1 = objget.get_data("https://{region}.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{gameName}/{tagLine}?api_key={api_key}", gameName="iResi", tagLine="BR1")
print(r1)
r1 = objget.get_data("https://{region}.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{gameName}/{tagLine}?api_key={api_key}", gameName="frosty", tagLine="KR3")
print(r1)
# Out:
# Requisititando dados de: https://AMERICAS.api.riotgames.com/riot/account/v1/accounts/by-riot-id/iResi/BR1?api_key=RGAPI-4125cf79-8553-489b-bc7a-da7510b581df
# Dados requisitados com sucesso
# {'puuid': 'smVq8PGKNLFVatly_fkSFLP_WLYlKULVsPGepMCWWqGMg3oq1ktg5fnporX3aKmiiFlZEApJEwY59w', 'gameName': 'iResi', 'tagLine': 'BR1'}
# Requisititando dados de: https://AMERICAS.api.riotgames.com/riot/account/v1/accounts/by-riot-id/frosty/KR3?api_key=RGAPI-4125cf79-8553-489b-bc7a-da7510b581df
# Dados requisitados com sucesso
# {'puuid': 'V6LrFdRy53bp_HtS_tKE-S8Ete52saUNFLuhFr2G-B2hj4jvpwDcY9cfzV3gOQtP_XTkaSU-WsCdwA', 'gameName': 'frosty', 'tagLine': 'KR3'}

# %%
import pandas as pd
df_challenger_daily = pd.read_parquet(f"D:/data/LOL/tb_challenger_daily.parquet")
display(df_challenger_daily)
# Out:
#                                           summonerId  leaguePoints rank  wins  \
# 0  ZmJFu-xTU7GiBQZFZ6-gs8H7hjmgpO_vqHnhYva2E1ceOk...           760    I    65
# 1    UE5iWu-jaemV3ZWBJN3yCHJuQTILj07AatKxZm_Xd61pGA8           504    I    54
#
#    losses  veteran  inactive  freshBlood  hotStreak  position dat_ref_carga
# 0      24    False     False        True      False         1    2024-10-03
# 1      25    False     False        True      False         2    2024-10-03

# %%
import pandas as pd
df_summoners = pd.read_parquet(f"D:/data/LOL/tb_summoners.parquet")
display(df_summoners)
# Out:
#                                            accountId  \
# 0    c26m5K0Hgzdgo_i_A43hM1FMCXcQ-OQ9iI66FGIEn5vZ--8
# 1  ZmQqLBRoqixhupFsdkkLyazAALw5yz0q1UC21Js9lVe94R...
#
#                                                puuid  profileIconId  \
# 0  V6LrFdRy53bp_HtS_tKE-S8Ete52saUNFLuhFr2G-B2hj4...           4856
# 1  WGbosCicZhJWiKjP7aHKasZ0KsifYht6t-pT0sjdUQ6yC6...           6498
#
#     revisionDate  summonerLevel last_dat_ref_carga  \
# 0  1727904649000            993         2024-10-03
# 1  1727993909153            146         2024-10-03
#
#                                                   id
# 0    UE5iWu-jaemV3ZWBJN3yCHJuQTILj07AatKxZm_Xd61pGA8
# 1  ZmJFu-xTU7GiBQZFZ6-gs8H7hjmgpO_vqHnhYva2E1ceOk...

# %%
import pandas as pd
df_summoners_hist = pd.read_parquet(f"D:/data/LOL/tb_summoners_hist.parquet")
display(df_summoners_hist)
# Out:
#                                           alter_data dat_ref_carga  \
# 0  {'accountId': 'c26m5K0Hgzdgo_i_A43hM1FMCXcQ-OQ...    2024-10-03
# 1  {'accountId': 'ZmQqLBRoqixhupFsdkkLyazAALw5yz0...    2024-10-03
#
#                                                   id
# 0    UE5iWu-jaemV3ZWBJN3yCHJuQTILj07AatKxZm_Xd61pGA8
# 1  ZmJFu-xTU7GiBQZFZ6-gs8H7hjmgpO_vqHnhYva2E1ceOk...

# %%
df_match_infos.groupby('matchId').count()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_13388\1345487900.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_match_infos.groupby('matchId').count()
#                 dataVersion  participants  allInPings  assistMePings  assists  \
# matchId
# BR1_3005764981           10            10          10             10       10
# BR1_3005797727           10            10          10             10       10
# BR1_3005866630           10            10          10             10       10
# BR1_3005876858           10            10          10             10       10
# BR1_3005961069           10            10          10             10       10
#
#                 baronKills  basicPings  bountyLevel  challenges  \
# matchId
# BR1_3005764981          10          10           10          10
# ...

# %%
import pandas as pd
df_match_infos = pd.read_parquet(f"D:/data/LOL/tb_matchs_infos.parquet")
display(df_match_infos)
# Out:
#    dataVersion                                       participants  allInPings  \
# 0            2  oAJ_fnNrPXJiyrX35i1HA1FxKZaHsJfsihFloew_aYM-gN...           0
# 1            2  WGbosCicZhJWiKjP7aHKasZ0KsifYht6t-pT0sjdUQ6yC6...           0
# 2            2  E2ZApw8VuNpLQKSMfrYguuzX4UhyczQAQrVqpgyT28nMQU...           2
# 3            2  6ZKwC5uTmLej3XcZsLjDqSgz_lSrKyUmsekHbSSFhrpE3k...           0
# 4            2  CcMrL8xJPe-NRKOyei68mtTEyqCQ80QYrdIyY2Y5Hb9hmQ...           0
# 5            2  Age_3iU9WvfXfgAzh_yxjFx0PAIU2azUSDtO23FpFv2xIp...           0
# 6            2  Htuf2guMchMvfxDjyFR2HuVPQmadqDsJGmB0gekRCK7bih...           2
# 7            2  Dsk_47rwX47kc4kSL6aPNMfZvWlRRQIDvvLxHOFEFWxCtP...           1
# 8            2  c2xkj2Dtw994qLQksfW7YKkyQxb_95JAXa4QjSxAIXNH1S...           0
# 9            2  dQoK_UFiD-CgDRMRhH9DldXasiZEVJFggbIZSlc4F5cNOa...           0
# 10           2  BvCdwTjyYwbesCnItNezhzd5tp86JHXhSPV-tuzUEAt8NE...           0
# ...

# %%
import pandas as pd
df_match_time = pd.read_parquet(f"D:/data/LOL/tb_matchs_timeline.parquet")
display(df_match_time)
# Out:
#      event  realTimestamp  timestamp  type  \
# 0      NaN            NaN        NaN  None
# 1      NaN            NaN        NaN  None
# 2      NaN            NaN        NaN  None
# 3      NaN            NaN        NaN  None
# 4      NaN            NaN        NaN  None
# ..     ...            ...        ...   ...
# 101    2.0            NaN   108013.0  None
# 102    2.0            NaN   108013.0  None
# 103    2.0            NaN   108013.0  None
# 104    2.0            NaN   108013.0  None
# 105    2.0            NaN   108013.0  None
#
#                                          championStats  currentGold  \
# 0                                                 None          NaN
# 1                                                 None          NaN
# 2                                                 None          NaN
# 3                                                 None          NaN
# 4                                                 None          NaN
# ...
